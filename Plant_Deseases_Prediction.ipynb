# %% [markdown]
# <a href="https://colab.research.google.com/github/tbenesi/Computer-Vision-Projects/blob/main/Plant_Deseases_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this project we will create a Convolutional Neural Network which will be able to predict whether a plant is suffering from a disease. We will use different layers and other hyperparameters for building, training and testing this classifictaion model.We will be using tensorflow and keras for this project.

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# First we will mount our google drive on colab so that we can use the dataset directly from our drive. For this you first need to upload the data on your drive and then mount the drive on colab.

# %%
# After executing the cell above, Drive
# files will be present in "/content/drive/My Drive".
# !ls "/content/drive/My Drive"
# Out:
#  CattleRearing.pdf
# 'Colab Notebooks'
#  Data
# 'Getting started.pdf'
# 'Mr. Tawanda Benesi.docx'
#  myCoverLetter.docx
#  study.zip
# 'Tawanda Benesi -  Statistic Courses - Teaching Assistant Evaluations.pdf'
#  T_Benesi_Resume_Dataiku.docx
#  Transcript_Tbenesi.pdf
#  UpdatedCV_TawandaBenesi.gdoc
#  UpdatedCV_TawandaBenesi.pdf
# 'UpdatedResume_TawandaBenesi (1).pdf'
#  UpdatedResume_TawandaBenesi.pdf

# %% [markdown]
# After mounting our drive we will locate the folder where our data is stored to use it in our colab notebook.
# Here you I have the folder 'Data' in my drive and subfolder 'Plant_images_pianlytix' contains the images that we will work on.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
import os
from os import listdir
from PIL import Image
from sklearn.preprocessing import label_binarize,  LabelBinarizer
from tensorflow.keras.preprocessing.image import img_to_array, array_to_img
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential


import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Flatten, Dropout, Dense
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import model_from_json
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# Next we will import all the required libraries. As we are making a CNN model we will import all the required layers, activations, optimizers, etc.

# %%
# Plotting 12 images to check dataset
plt.figure(figsize=(12,12))
path = "/content/drive/My Drive/Data/Plant_images_pianalytix/Potato___Early_blight"
for i in range(1,17):
    plt.subplot(4,4,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(os.listdir(path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10)#width of image
    plt.ylabel(rand_img.shape[0], fontsize = 10)#height of image

# %% [markdown]
# Now we will observe some of the iamges that are their in our dataset. We will plot 12 images here using the matplotlib library.

# %%
#Converting Images to array
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, (256,256))
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %% [markdown]
# After visualizing the images let us move forward and create a function which will convert the images into a numpy array. It is required because we will normalize our dataset after this.

# %%
dir = "/content/drive/My Drive/Data/Plant_images_pianalytix"
root_dir = listdir(dir)
image_list, label_list = [], []
all_labels = ['Corn-Common_rust', 'Potato-Early_blight', 'Tomato-Bacterial_spot']
binary_labels = [0,1,2]
temp = -1

# Reading and converting image to numpy array
for directory in root_dir:
  plant_image_list = listdir(f"{dir}/{directory}")
  temp += 1
  for files in plant_image_list:
    image_path = f"{dir}/{directory}/{files}"
    image_list.append(convert_image_to_array(image_path))
    label_list.append(binary_labels[temp])

# %% [markdown]
# Now we will convert all the images into numpy array.

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts.head()
# Out:
# 0    300
# 1    300
# 2    300
# dtype: int64

# %% [markdown]
# We will also observe the number of images under different classes to see if the dataset is balanced or not

# %%
image_list[0].shape
# Out:
# (256, 256, 3)

# %% [markdown]
# Next we will observe the shape of the image.

# %%
label_list = np.array(label_list)
label_list.shape
# Out:
# (900,)

# %% [markdown]
# Checking the total number of the images which is the length of the labels list.

# %%
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %% [markdown]
# Next we will use sklearn train_test_split to split the dataset into testing and training data. Here I have taken test size as 0.2 so my data will be divided into 80% training and 20% testing data.

# %%
x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape( -1, 256,256,3)
x_test = x_test.reshape( -1, 256,256,3)

# %% [markdown]
# Now we will normalize the dataset of our images. As pixel values ranges from 0 to 255 so we will divide each image pixel with 255 to normalize the dataset.

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding="same",input_shape=(256,256,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(8, activation="relu"))
model.add(Dense(3, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 85, 85, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 85, 85, 16)        4624
#
#  max_pooling2d_1 (MaxPooling  (None, 42, 42, 16)       0
#  2D)
#
#  flatten (Flatten)           (None, 28224)             0
#
#  dense (Dense)               (None, 8)                 225800
#
#  dense_1 (Dense)             (None, 3)                 27
#
# =================================================================
# Total params: 231,347
# Trainable params: 231,347
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Next we will create a network architecture for the model. We have used different types of layers according to their features namely Conv_2d (It is used to create a convolutional kernel that is convolved with the input layer to produce the output tensor), max_pooling2d (It is a downsampling technique which takes out the maximum value over the window defined by poolsize), flatten (It flattens the input and creates a 1D output), Dense (Dense layer produce the output as the dot product of input and kernel).

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0001),metrics=['accuracy'])

# %% [markdown]
# While compiling the model we need to set the type of loss which will be Binary Crossentropy for our model alongwith this we also need to set the optimizer and the metrics respectively.

# %%
# Splitting the training data set into training and validation data sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %% [markdown]
# Next we will split the dataset into validation and training data.

# %%
# Training the model
epochs = 100
batch_size = 256
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs,
                    validation_data = (x_val, y_val))
# Out:
# Epoch 1/100
# 2/2 [==============================] - 18s 3s/step - loss: 1.0842 - accuracy: 0.4630 - val_loss: 1.0398 - val_accuracy: 0.3362
# Epoch 2/100
# 2/2 [==============================] - 1s 309ms/step - loss: 1.0420 - accuracy: 0.3304 - val_loss: 1.0018 - val_accuracy: 0.3707
# Epoch 3/100
# 2/2 [==============================] - 1s 353ms/step - loss: 1.0061 - accuracy: 0.4065 - val_loss: 0.9619 - val_accuracy: 0.6207
# Epoch 4/100
# 2/2 [==============================] - 1s 358ms/step - loss: 0.9629 - accuracy: 0.5935 - val_loss: 0.9277 - val_accuracy: 0.6552
# Epoch 5/100
# 2/2 [==============================] - 1s 310ms/step - loss: 0.9266 - accuracy: 0.6435 - val_loss: 0.8908 - val_accuracy: 0.6552
# Epoch 6/100
# 2/2 [==============================] - 1s 350ms/step - loss: 0.8888 - accuracy: 0.6457 - val_loss: 0.8544 - val_accuracy: 0.6552
# Epoch 7/100
# 2/2 [==============================] - 1s 352ms/step - loss: 0.8527 - accuracy: 0.6413 - val_loss: 0.8184 - val_accuracy: 0.6638
# Epoch 8/100
# 2/2 [==============================] - 1s 320ms/step - loss: 0.8185 - accuracy: 0.6478 - val_loss: 0.7839 - val_accuracy: 0.6638
# Epoch 9/100
# 2/2 [==============================] - 1s 346ms/step - loss: 0.7812 - accuracy: 0.6543 - val_loss: 0.7510 - val_accuracy: 0.6724
# Epoch 10/100
# 2/2 [==============================] - 1s 303ms/step - loss: 0.7475 - accuracy: 0.6565 - val_loss: 0.7206 - val_accuracy: 0.6724
# Epoch 11/100
# 2/2 [==============================] - 1s 396ms/step - loss: 0.7161 - accuracy: 0.6565 - val_loss: 0.6866 - val_accuracy: 0.6724
# Epoch 12/100
# 2/2 [==============================] - 1s 380ms/step - loss: 0.6817 - accuracy: 0.6565 - val_loss: 0.6551 - val_accuracy: 0.6724
# Epoch 13/100
# 2/2 [==============================] - 1s 386ms/step - loss: 0.6512 - accuracy: 0.6565 - val_loss: 0.6264 - val_accuracy: 0.6724
# Epoch 14/100
# 2/2 [==============================] - 1s 402ms/step - loss: 0.6225 - accuracy: 0.6565 - val_loss: 0.5985 - val_accuracy: 0.6724
# Epoch 15/100
# 2/2 [==============================] - 1s 403ms/step - loss: 0.5955 - accuracy: 0.6565 - val_loss: 0.5728 - val_accuracy: 0.6724
# Epoch 16/100
# 2/2 [==============================] - 1s 340ms/step - loss: 0.5703 - accuracy: 0.6609 - val_loss: 0.5543 - val_accuracy: 0.6724
# Epoch 17/100
# 2/2 [==============================] - 1s 304ms/step - loss: 0.5441 - accuracy: 0.6717 - val_loss: 0.5241 - val_accuracy: 0.6724
# Epoch 18/100
# 2/2 [==============================] - 1s 304ms/step - loss: 0.5178 - accuracy: 0.6717 - val_loss: 0.4976 - val_accuracy: 0.6724
# Epoch 19/100
# 2/2 [==============================] - 1s 303ms/step - loss: 0.4941 - accuracy: 0.6739 - val_loss: 0.4737 - val_accuracy: 0.7069
# Epoch 20/100
# 2/2 [==============================] - 1s 300ms/step - loss: 0.4684 - accuracy: 0.7152 - val_loss: 0.4511 - val_accuracy: 0.7931
# Epoch 21/100
# 2/2 [==============================] - 1s 355ms/step - loss: 0.4434 - accuracy: 0.8065 - val_loss: 0.4284 - val_accuracy: 0.8793
# Epoch 22/100
# 2/2 [==============================] - 1s 367ms/step - loss: 0.4194 - accuracy: 0.8739 - val_loss: 0.3986 - val_accuracy: 0.8966
# Epoch 23/100
# 2/2 [==============================] - 1s 347ms/step - loss: 0.3939 - accuracy: 0.8739 - val_loss: 0.3719 - val_accuracy: 0.9310
# Epoch 24/100
# 2/2 [==============================] - 1s 321ms/step - loss: 0.3702 - accuracy: 0.9043 - val_loss: 0.3505 - val_accuracy: 0.9655
# Epoch 25/100
# 2/2 [==============================] - 1s 360ms/step - loss: 0.3463 - accuracy: 0.9435 - val_loss: 0.3284 - val_accuracy: 0.9828
# Epoch 26/100
# 2/2 [==============================] - 1s 312ms/step - loss: 0.3232 - accuracy: 0.9609 - val_loss: 0.3015 - val_accuracy: 0.9828
# Epoch 27/100
# 2/2 [==============================] - 1s 309ms/step - loss: 0.3019 - accuracy: 0.9500 - val_loss: 0.2801 - val_accuracy: 0.9828
# Epoch 28/100
# 2/2 [==============================] - 1s 310ms/step - loss: 0.2811 - accuracy: 0.9804 - val_loss: 0.2626 - val_accuracy: 0.9828
# Epoch 29/100
# 2/2 [==============================] - 1s 308ms/step - loss: 0.2609 - accuracy: 0.9913 - val_loss: 0.2390 - val_accuracy: 0.9828
# Epoch 30/100
# 2/2 [==============================] - 1s 306ms/step - loss: 0.2436 - accuracy: 0.9826 - val_loss: 0.2214 - val_accuracy: 0.9828
# Epoch 31/100
# 2/2 [==============================] - 1s 349ms/step - loss: 0.2247 - accuracy: 0.9935 - val_loss: 0.2131 - val_accuracy: 1.0000
# Epoch 32/100
# 2/2 [==============================] - 1s 314ms/step - loss: 0.2116 - accuracy: 0.9935 - val_loss: 0.1903 - val_accuracy: 0.9914
# Epoch 33/100
# 2/2 [==============================] - 1s 325ms/step - loss: 0.1981 - accuracy: 0.9891 - val_loss: 0.1759 - val_accuracy: 0.9828
# Epoch 34/100
# 2/2 [==============================] - 1s 344ms/step - loss: 0.1852 - accuracy: 0.9891 - val_loss: 0.1715 - val_accuracy: 1.0000
# Epoch 35/100
# 2/2 [==============================] - 1s 403ms/step - loss: 0.1723 - accuracy: 0.9935 - val_loss: 0.1528 - val_accuracy: 1.0000
# Epoch 36/100
# 2/2 [==============================] - 1s 378ms/step - loss: 0.1600 - accuracy: 0.9935 - val_loss: 0.1433 - val_accuracy: 1.0000
# Epoch 37/100
# 2/2 [==============================] - 1s 394ms/step - loss: 0.1493 - accuracy: 0.9935 - val_loss: 0.1358 - val_accuracy: 1.0000
# Epoch 38/100
# 2/2 [==============================] - 1s 415ms/step - loss: 0.1407 - accuracy: 0.9935 - val_loss: 0.1251 - val_accuracy: 1.0000
# Epoch 39/100
# 2/2 [==============================] - 1s 405ms/step - loss: 0.1335 - accuracy: 0.9935 - val_loss: 0.1163 - val_accuracy: 1.0000
# Epoch 40/100
# 2/2 [==============================] - 1s 380ms/step - loss: 0.1238 - accuracy: 0.9935 - val_loss: 0.1154 - val_accuracy: 1.0000
# Epoch 41/100
# 2/2 [==============================] - 1s 308ms/step - loss: 0.1183 - accuracy: 0.9935 - val_loss: 0.1029 - val_accuracy: 1.0000
# Epoch 42/100
# 2/2 [==============================] - 1s 310ms/step - loss: 0.1121 - accuracy: 0.9935 - val_loss: 0.0963 - val_accuracy: 1.0000
# Epoch 43/100
# 2/2 [==============================] - 1s 349ms/step - loss: 0.1041 - accuracy: 0.9935 - val_loss: 0.0979 - val_accuracy: 1.0000
# Epoch 44/100
# 2/2 [==============================] - 1s 310ms/step - loss: 0.1004 - accuracy: 0.9935 - val_loss: 0.0870 - val_accuracy: 1.0000
# Epoch 45/100
# 2/2 [==============================] - 1s 318ms/step - loss: 0.0936 - accuracy: 0.9935 - val_loss: 0.0807 - val_accuracy: 1.0000
# Epoch 46/100
# 2/2 [==============================] - 1s 348ms/step - loss: 0.0896 - accuracy: 0.9935 - val_loss: 0.0793 - val_accuracy: 1.0000
# Epoch 47/100
# 2/2 [==============================] - 1s 306ms/step - loss: 0.0842 - accuracy: 0.9935 - val_loss: 0.0733 - val_accuracy: 1.0000
# Epoch 48/100
# 2/2 [==============================] - 1s 351ms/step - loss: 0.0797 - accuracy: 0.9935 - val_loss: 0.0688 - val_accuracy: 1.0000
# Epoch 49/100
# 2/2 [==============================] - 1s 304ms/step - loss: 0.0760 - accuracy: 0.9935 - val_loss: 0.0652 - val_accuracy: 1.0000
# Epoch 50/100
# 2/2 [==============================] - 1s 306ms/step - loss: 0.0723 - accuracy: 0.9935 - val_loss: 0.0627 - val_accuracy: 1.0000
# Epoch 51/100
# 2/2 [==============================] - 1s 306ms/step - loss: 0.0690 - accuracy: 0.9935 - val_loss: 0.0605 - val_accuracy: 1.0000
# Epoch 52/100
# 2/2 [==============================] - 1s 316ms/step - loss: 0.0657 - accuracy: 0.9935 - val_loss: 0.0560 - val_accuracy: 1.0000
# Epoch 53/100
# 2/2 [==============================] - 1s 349ms/step - loss: 0.0629 - accuracy: 0.9935 - val_loss: 0.0532 - val_accuracy: 1.0000
# Epoch 54/100
# 2/2 [==============================] - 1s 353ms/step - loss: 0.0600 - accuracy: 0.9935 - val_loss: 0.0512 - val_accuracy: 1.0000
# Epoch 55/100
# 2/2 [==============================] - 1s 353ms/step - loss: 0.0573 - accuracy: 0.9935 - val_loss: 0.0488 - val_accuracy: 1.0000
# Epoch 56/100
# 2/2 [==============================] - 1s 304ms/step - loss: 0.0547 - accuracy: 0.9935 - val_loss: 0.0459 - val_accuracy: 1.0000
# Epoch 57/100
# 2/2 [==============================] - 1s 308ms/step - loss: 0.0524 - accuracy: 0.9935 - val_loss: 0.0438 - val_accuracy: 1.0000
# Epoch 58/100
# 2/2 [==============================] - 1s 363ms/step - loss: 0.0499 - accuracy: 0.9935 - val_loss: 0.0432 - val_accuracy: 1.0000
# Epoch 59/100
# 2/2 [==============================] - 1s 475ms/step - loss: 0.0480 - accuracy: 0.9935 - val_loss: 0.0401 - val_accuracy: 1.0000
# Epoch 60/100
# 2/2 [==============================] - 1s 393ms/step - loss: 0.0457 - accuracy: 0.9935 - val_loss: 0.0378 - val_accuracy: 1.0000
# Epoch 61/100
# 2/2 [==============================] - 1s 402ms/step - loss: 0.0441 - accuracy: 0.9957 - val_loss: 0.0367 - val_accuracy: 1.0000
# Epoch 62/100
# 2/2 [==============================] - 1s 361ms/step - loss: 0.0421 - accuracy: 0.9935 - val_loss: 0.0360 - val_accuracy: 1.0000
# Epoch 63/100
# 2/2 [==============================] - 1s 420ms/step - loss: 0.0407 - accuracy: 0.9935 - val_loss: 0.0337 - val_accuracy: 1.0000
# Epoch 64/100
# 2/2 [==============================] - 1s 348ms/step - loss: 0.0401 - accuracy: 0.9935 - val_loss: 0.0319 - val_accuracy: 1.0000
# Epoch 65/100
# 2/2 [==============================] - 1s 357ms/step - loss: 0.0386 - accuracy: 0.9935 - val_loss: 0.0323 - val_accuracy: 1.0000
# Epoch 66/100
# 2/2 [==============================] - 1s 306ms/step - loss: 0.0364 - accuracy: 0.9935 - val_loss: 0.0296 - val_accuracy: 1.0000
# Epoch 67/100
# 2/2 [==============================] - 1s 353ms/step - loss: 0.0359 - accuracy: 0.9957 - val_loss: 0.0287 - val_accuracy: 1.0000
# Epoch 68/100
# 2/2 [==============================] - 1s 362ms/step - loss: 0.0337 - accuracy: 0.9957 - val_loss: 0.0300 - val_accuracy: 1.0000
# Epoch 69/100
# 2/2 [==============================] - 1s 302ms/step - loss: 0.0336 - accuracy: 0.9935 - val_loss: 0.0271 - val_accuracy: 1.0000
# Epoch 70/100
# 2/2 [==============================] - 1s 352ms/step - loss: 0.0323 - accuracy: 0.9957 - val_loss: 0.0262 - val_accuracy: 1.0000
# Epoch 71/100
# 2/2 [==============================] - 1s 309ms/step - loss: 0.0312 - accuracy: 0.9957 - val_loss: 0.0263 - val_accuracy: 1.0000
# Epoch 72/100
# 2/2 [==============================] - 1s 309ms/step - loss: 0.0310 - accuracy: 0.9978 - val_loss: 0.0255 - val_accuracy: 1.0000
# Epoch 73/100
# 2/2 [==============================] - 1s 313ms/step - loss: 0.0288 - accuracy: 0.9978 - val_loss: 0.0240 - val_accuracy: 1.0000
# Epoch 74/100
# 2/2 [==============================] - 1s 303ms/step - loss: 0.0290 - accuracy: 1.0000 - val_loss: 0.0231 - val_accuracy: 1.0000
# Epoch 75/100
# 2/2 [==============================] - 1s 304ms/step - loss: 0.0270 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 1.0000
# Epoch 76/100
# 2/2 [==============================] - 1s 308ms/step - loss: 0.0278 - accuracy: 0.9957 - val_loss: 0.0225 - val_accuracy: 1.0000
# Epoch 77/100
# 2/2 [==============================] - 1s 322ms/step - loss: 0.0268 - accuracy: 1.0000 - val_loss: 0.0218 - val_accuracy: 1.0000
# Epoch 78/100
# 2/2 [==============================] - 1s 352ms/step - loss: 0.0261 - accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 1.0000
# Epoch 79/100
# 2/2 [==============================] - 1s 306ms/step - loss: 0.0243 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 1.0000
# Epoch 80/100
# 2/2 [==============================] - 1s 353ms/step - loss: 0.0249 - accuracy: 0.9957 - val_loss: 0.0196 - val_accuracy: 1.0000
# Epoch 81/100
# 2/2 [==============================] - 1s 363ms/step - loss: 0.0230 - accuracy: 1.0000 - val_loss: 0.0193 - val_accuracy: 1.0000
# Epoch 82/100
# 2/2 [==============================] - 1s 345ms/step - loss: 0.0232 - accuracy: 1.0000 - val_loss: 0.0187 - val_accuracy: 1.0000
# Epoch 83/100
# 2/2 [==============================] - 1s 399ms/step - loss: 0.0218 - accuracy: 1.0000 - val_loss: 0.0196 - val_accuracy: 1.0000
# Epoch 84/100
# 2/2 [==============================] - 1s 444ms/step - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.0180 - val_accuracy: 1.0000
# Epoch 85/100
# 2/2 [==============================] - 1s 416ms/step - loss: 0.0213 - accuracy: 1.0000 - val_loss: 0.0177 - val_accuracy: 1.0000
# Epoch 86/100
# 2/2 [==============================] - 1s 406ms/step - loss: 0.0212 - accuracy: 1.0000 - val_loss: 0.0174 - val_accuracy: 1.0000
# Epoch 87/100
# 2/2 [==============================] - 1s 393ms/step - loss: 0.0206 - accuracy: 1.0000 - val_loss: 0.0191 - val_accuracy: 1.0000
# Epoch 88/100
# 2/2 [==============================] - 1s 353ms/step - loss: 0.0201 - accuracy: 1.0000 - val_loss: 0.0163 - val_accuracy: 1.0000
# Epoch 89/100
# 2/2 [==============================] - 1s 314ms/step - loss: 0.0196 - accuracy: 1.0000 - val_loss: 0.0161 - val_accuracy: 1.0000
# Epoch 90/100
# 2/2 [==============================] - 1s 307ms/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.0164 - val_accuracy: 1.0000
# Epoch 91/100
# 2/2 [==============================] - 1s 308ms/step - loss: 0.0183 - accuracy: 1.0000 - val_loss: 0.0166 - val_accuracy: 1.0000
# Epoch 92/100
# 2/2 [==============================] - 1s 305ms/step - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.0149 - val_accuracy: 1.0000
# Epoch 93/100
# 2/2 [==============================] - 1s 306ms/step - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.0153 - val_accuracy: 1.0000
# Epoch 94/100
# 2/2 [==============================] - 1s 305ms/step - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.0144 - val_accuracy: 1.0000
# Epoch 95/100
# 2/2 [==============================] - 1s 356ms/step - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.0166 - val_accuracy: 1.0000
# Epoch 96/100
# 2/2 [==============================] - 1s 305ms/step - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.0136 - val_accuracy: 1.0000
# Epoch 97/100
# 2/2 [==============================] - 1s 353ms/step - loss: 0.0159 - accuracy: 1.0000 - val_loss: 0.0135 - val_accuracy: 1.0000
# Epoch 98/100
# 2/2 [==============================] - 1s 311ms/step - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.0132 - val_accuracy: 1.0000
# Epoch 99/100
# 2/2 [==============================] - 1s 354ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.0141 - val_accuracy: 1.0000
# Epoch 100/100
# 2/2 [==============================] - 1s 359ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.0126 - val_accuracy: 1.0000

# %% [markdown]
# Fitting the model with the data and finding out the accuracy at each epoch to see how our model is learning. Now we will train our model on 10 epochs and a batch size of 128. You can try using more number of epochs to increase accuracy but here we can see that the model has already raeched a very high accuracy so we don't need to run it for more. During each epochs we can see how the model is performing by viewing the training and validation accuracy.

# %%
model.save("/content/drive/My Drive/plant_disease.h5")
# serialize model to json
json_model = model.to_json()
#save the model architecture to JSON file
with open('/content/drive/My Drive/plant_model.json', 'w') as json_file:
    json_file.write(json_model)
#saving the weights of the model
model.save_weights('/content/drive/My Drive/plant_model_weights.h5')

# %% [markdown]
# Saving the model using different techniques.

# %%
#Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %% [markdown]
# Next we will plot the accuracy of the model for the trainig history.

# %%
print("[INFO] Calculating model accuracy")
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 6/6 [==============================] - 1s 43ms/step - loss: 0.0143 - accuracy: 1.0000
# Test Accuracy: 100.0

# %% [markdown]
# Evaluating the model to know the accuracy of the model.

# %%
y_pred = model.predict(x_test)
# Out:
# 6/6 [==============================] - 0s 18ms/step

# %% [markdown]
# Next we will use our model to predict predicting the testing dataset label.

# %%
# Plotting image to compare
img = array_to_img(x_test[10])
img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
# Finding max value from predition list and comaparing original value vs predicted
print("Originally : ",all_labels[np.argmax(y_test[10])])
print("Predicted : ",all_labels[np.argmax(y_pred[10])])
# Out:
# Originally :  Potato-Early_blight
# Predicted :  Potato-Early_blight

# %% [markdown]
# Printing out the original and the predicted label.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# We started with loading the dataset into google colab using google drive and visualizing the images. Normalizing is an important step when working with any type of dataset. After that we created a CNN Model which is further used for predicting the plant diseases using the image supplied to model.
# This model is highly beneficial as it can be used by different agricultural firms and farmers to increase their yield and stop wastage of crops due to disease.
