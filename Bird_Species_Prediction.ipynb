# %% [markdown]
# <a href="https://colab.research.google.com/github/tbenesi/Computer-Vision-Projects/blob/main/Bird_Species_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bird Species Prediction

# %% [markdown]
# In this project we will create a Convolutional Neural Network which will be able to predict species of the bird. We will use different layers and other hyperparameters for building, training and testing this multiclass classifictaion model. We will be using keras for this project.

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# First we will mount our google drive on colab so that we can use the dataset directly from our drive. For this you first need to upload the data on your drive and then mount the drive on colab.

# %%
# After executing the cell above, Drive files will be present in "/content/drive/My Drive".
# !ls "/content/drive/My Drive"
# Out:
# 'Bird Species Dataset'
#  CattleRearing.pdf
# 'Colab Notebooks'
#  Data
# 'Getting started.pdf'
# 'Mr. Tawanda Benesi.docx'
#  myCoverLetter.docx
#  plant_disease.h5
#  plant_model.json
#  plant_model_weights.h5
#  study.zip
# 'Tawanda Benesi -  Statistic Courses - Teaching Assistant Evaluations.pdf'
#  T_Benesi_Resume_Dataiku.docx
#  Transcript_Tbenesi.pdf
#  UpdatedCV_TawandaBenesi.gdoc
#  UpdatedCV_TawandaBenesi.pdf
# 'UpdatedResume_TawandaBenesi (1).pdf'
#  UpdatedResume_TawandaBenesi.pdf

# %% [markdown]
# After mounting our drive we will locate the folder where our data is stored to use it in our colab notebook. Here you can see that all the folders I have in my drive and 'Bird Species Dataset' contains the images that we will work on.

# %%
# Library imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
from os import listdir
from sklearn.preprocessing import  LabelBinarizer
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import img_to_array, array_to_img
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense
from sklearn.model_selection import train_test_split

# %% [markdown]
# We will start by importing some required libraries.

# %%
# Plotting 12 images to check dataset
plt.figure(figsize=(12,12))
path = "/content/drive/My Drive/Bird Species Dataset/AMERICAN GOLDFINCH"
for i in range(1,17):
    plt.subplot(4,4,i)
    plt.tight_layout()
    #print("Current path:", path)
    file_list = sorted(listdir(path))
    #print("List of files:", file_list)
    rand_img = imread(path +'/'+ random.choice(file_list))
    #print("Selected image:", rand_img)
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10)
    plt.ylabel(rand_img.shape[0], fontsize = 10)

# %% [markdown]
# Let's visualize some of the bird images that we will be working on. Also we will observe x and y dimensions of the image.

# %%
# Setting path and creating empty list
dir = "/content/drive/My Drive/Bird Species Dataset"
root_dir = listdir(dir)
image_list, label_list = [], []

# %% [markdown]
# Setting the root directory for the dataset and storing all the floders name of the dataset. We will also create 2 empty list for image and lables.

# %%
# Reading and converting image to numpy array
for directory in root_dir:
  for files in listdir(f"{dir}/{directory}"):
    image_path = f"{dir}/{directory}/{files}"
    image = cv2.imread(image_path)
    image = img_to_array(image)
    image_list.append(image)
    label_list.append(directory)

# %% [markdown]
# Next we will read all the images and convert it into array and appending the list created above with the image and its label.

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts
# Out:
# AMERICAN GOLDFINCH    143
# EMPEROR PENGUIN       139
# DOWNY WOODPECKER      137
# FLAMINGO              132
# CARMINE BEE-EATER     131
# BARN OWL              129
# dtype: int64

# %% [markdown]
# Check for class imbalance.

# %%
# Storing number of classes
num_classes = len(label_counts)
num_classes
# Out:
# 6

# %% [markdown]
# Next we will find out the number of classes that we will be working on.

# %%
# Checking input image shape
image_list[0].shape
# Out:
# (224, 224, 3)

# %% [markdown]
# Checking the size of the single image.

# %%
# Checking labels shape
label_list = np.array(label_list)
label_list.shape
# Out:
# (811,)

# %% [markdown]
# Checking the shape of image labels which will be equal to the number of images we are going to work with.

# %%
# Splitting dataset
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %% [markdown]
# Now we will split the data into training and testing using train_test_split() of sklearn.

# %%
# Normalize and reshape data
x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape( -1, 224,224,3)
x_test = x_test.reshape( -1, 224,224,3)

# %% [markdown]
# Next we will normalize the images by dividing them with 255. Also, we will reshape x_train and x_test.

# %%
# Label binarizing
lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.fit_transform(y_test)
print(lb.classes_)
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER'
#  'EMPEROR PENGUIN' 'FLAMINGO']

# %% [markdown]
# Next we will use label binarizer to one hot encode our y data. We will also print the sequence of the classes.

# %%
# Splitting the training data set into training and validation data sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %% [markdown]
# Now we will split the training data to validation and training data.

# %%
# Building model architecture
model = Sequential()
model.add(Conv2D(8, (3, 3), padding="same",input_shape=(224,224,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(32, activation="relu"))
model.add(Dense(num_classes, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 8)       224
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 8)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 74, 74, 16)        1168
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 16)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 37, 37, 32)        4640
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 10368)             0
#
#  dense (Dense)               (None, 32)                331808
#
#  dense_1 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 338,038
# Trainable params: 338,038
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Next we will create a network architecture for the model. We have used different types of layers according to their features namely Conv_2d (It is used to create a convolutional kernel that is convolved with the input layer to produce the output tensor), max_pooling2d (It is a downsampling technique which takes out the maximum value over the window defined by poolsize), flatten (It flattens the input and creates a 1D output), Dense (Dense layer produce the output as the dot product of input and kernel). In the last layer we will use softmax as the activation function because it is a multi class classification problem.

# %%
# Compiling model
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0005),metrics=['accuracy'])

# %% [markdown]
# While compiling the model we need to set the type of loss which will be Categorical Crossentropy for our model alongwith this we also need to set the optimizer and the metrics respectively.

# %%
# Training the model
epochs = 50
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 14s 232ms/step - loss: 1.8084 - accuracy: 0.1931 - val_loss: 1.7846 - val_accuracy: 0.2615
# Epoch 2/50
# 5/5 [==============================] - 0s 79ms/step - loss: 1.7738 - accuracy: 0.2471 - val_loss: 1.7798 - val_accuracy: 0.1923
# Epoch 3/50
# 5/5 [==============================] - 0s 95ms/step - loss: 1.7685 - accuracy: 0.2085 - val_loss: 1.7691 - val_accuracy: 0.1462
# Epoch 4/50
# 5/5 [==============================] - 0s 79ms/step - loss: 1.7529 - accuracy: 0.2220 - val_loss: 1.7523 - val_accuracy: 0.1769
# Epoch 5/50
# 5/5 [==============================] - 0s 77ms/step - loss: 1.7283 - accuracy: 0.2819 - val_loss: 1.7191 - val_accuracy: 0.2846
# Epoch 6/50
# 5/5 [==============================] - 0s 83ms/step - loss: 1.7042 - accuracy: 0.3263 - val_loss: 1.6870 - val_accuracy: 0.3154
# Epoch 7/50
# 5/5 [==============================] - 0s 77ms/step - loss: 1.6602 - accuracy: 0.3571 - val_loss: 1.6601 - val_accuracy: 0.2923
# Epoch 8/50
# 5/5 [==============================] - 0s 80ms/step - loss: 1.6245 - accuracy: 0.4054 - val_loss: 1.6105 - val_accuracy: 0.4846
# Epoch 9/50
# 5/5 [==============================] - 0s 78ms/step - loss: 1.5629 - accuracy: 0.4363 - val_loss: 1.5417 - val_accuracy: 0.3462
# Epoch 10/50
# 5/5 [==============================] - 0s 77ms/step - loss: 1.4886 - accuracy: 0.3764 - val_loss: 1.4847 - val_accuracy: 0.3769
# Epoch 11/50
# 5/5 [==============================] - 0s 77ms/step - loss: 1.4242 - accuracy: 0.4151 - val_loss: 1.4921 - val_accuracy: 0.3462
# Epoch 12/50
# 5/5 [==============================] - 0s 94ms/step - loss: 1.4122 - accuracy: 0.3977 - val_loss: 1.3834 - val_accuracy: 0.4000
# Epoch 13/50
# 5/5 [==============================] - 0s 78ms/step - loss: 1.3314 - accuracy: 0.4305 - val_loss: 1.3643 - val_accuracy: 0.4308
# Epoch 14/50
# 5/5 [==============================] - 0s 95ms/step - loss: 1.2401 - accuracy: 0.4788 - val_loss: 1.2899 - val_accuracy: 0.4846
# Epoch 15/50
# 5/5 [==============================] - 0s 79ms/step - loss: 1.2483 - accuracy: 0.5232 - val_loss: 1.2504 - val_accuracy: 0.4923
# Epoch 16/50
# 5/5 [==============================] - 0s 99ms/step - loss: 1.1881 - accuracy: 0.5097 - val_loss: 1.2724 - val_accuracy: 0.4615
# Epoch 17/50
# 5/5 [==============================] - 1s 119ms/step - loss: 1.1313 - accuracy: 0.5251 - val_loss: 1.2974 - val_accuracy: 0.4615
# Epoch 18/50
# 5/5 [==============================] - 1s 109ms/step - loss: 1.1300 - accuracy: 0.5502 - val_loss: 1.2375 - val_accuracy: 0.5000
# Epoch 19/50
# 5/5 [==============================] - 1s 123ms/step - loss: 1.1868 - accuracy: 0.5116 - val_loss: 1.2301 - val_accuracy: 0.5077
# Epoch 20/50
# 5/5 [==============================] - 1s 117ms/step - loss: 1.0819 - accuracy: 0.5927 - val_loss: 1.2361 - val_accuracy: 0.5538
# Epoch 21/50
# 5/5 [==============================] - 1s 117ms/step - loss: 1.0726 - accuracy: 0.5965 - val_loss: 1.1559 - val_accuracy: 0.5385
# Epoch 22/50
# 5/5 [==============================] - 1s 116ms/step - loss: 0.9964 - accuracy: 0.5869 - val_loss: 1.1931 - val_accuracy: 0.5154
# Epoch 23/50
# 5/5 [==============================] - 0s 79ms/step - loss: 0.9377 - accuracy: 0.6158 - val_loss: 1.1287 - val_accuracy: 0.5462
# Epoch 24/50
# 5/5 [==============================] - 0s 79ms/step - loss: 0.9068 - accuracy: 0.6409 - val_loss: 1.1263 - val_accuracy: 0.5385
# Epoch 25/50
# 5/5 [==============================] - 0s 93ms/step - loss: 0.9479 - accuracy: 0.6506 - val_loss: 1.1474 - val_accuracy: 0.5615
# Epoch 26/50
# 5/5 [==============================] - 0s 95ms/step - loss: 0.8477 - accuracy: 0.7181 - val_loss: 1.0646 - val_accuracy: 0.6000
# Epoch 27/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.8369 - accuracy: 0.7220 - val_loss: 1.0364 - val_accuracy: 0.6154
# Epoch 28/50
# 5/5 [==============================] - 0s 91ms/step - loss: 0.7998 - accuracy: 0.7452 - val_loss: 0.9953 - val_accuracy: 0.6231
# Epoch 29/50
# 5/5 [==============================] - 0s 92ms/step - loss: 0.7358 - accuracy: 0.7490 - val_loss: 0.9614 - val_accuracy: 0.6462
# Epoch 30/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.7043 - accuracy: 0.7761 - val_loss: 0.9749 - val_accuracy: 0.6769
# Epoch 31/50
# 5/5 [==============================] - 0s 92ms/step - loss: 0.6883 - accuracy: 0.7703 - val_loss: 0.9262 - val_accuracy: 0.6385
# Epoch 32/50
# 5/5 [==============================] - 0s 80ms/step - loss: 0.6619 - accuracy: 0.7625 - val_loss: 0.8794 - val_accuracy: 0.6769
# Epoch 33/50
# 5/5 [==============================] - 0s 78ms/step - loss: 0.6075 - accuracy: 0.7973 - val_loss: 0.9190 - val_accuracy: 0.7077
# Epoch 34/50
# 5/5 [==============================] - 0s 92ms/step - loss: 0.5765 - accuracy: 0.8263 - val_loss: 0.8688 - val_accuracy: 0.7538
# Epoch 35/50
# 5/5 [==============================] - 0s 98ms/step - loss: 0.5616 - accuracy: 0.8224 - val_loss: 0.8430 - val_accuracy: 0.7385
# Epoch 36/50
# 5/5 [==============================] - 0s 77ms/step - loss: 0.5681 - accuracy: 0.8031 - val_loss: 0.8503 - val_accuracy: 0.7385
# Epoch 37/50
# 5/5 [==============================] - 0s 93ms/step - loss: 0.5287 - accuracy: 0.8552 - val_loss: 0.8411 - val_accuracy: 0.7077
# Epoch 38/50
# 5/5 [==============================] - 0s 79ms/step - loss: 0.4881 - accuracy: 0.8687 - val_loss: 0.7735 - val_accuracy: 0.7385
# Epoch 39/50
# 5/5 [==============================] - 0s 93ms/step - loss: 0.4876 - accuracy: 0.8398 - val_loss: 0.8042 - val_accuracy: 0.7538
# Epoch 40/50
# 5/5 [==============================] - 0s 79ms/step - loss: 0.4600 - accuracy: 0.8494 - val_loss: 0.7477 - val_accuracy: 0.7615
# Epoch 41/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.4377 - accuracy: 0.8552 - val_loss: 0.7499 - val_accuracy: 0.7308
# Epoch 42/50
# 5/5 [==============================] - 0s 91ms/step - loss: 0.4147 - accuracy: 0.8784 - val_loss: 0.7487 - val_accuracy: 0.7692
# Epoch 43/50
# 5/5 [==============================] - 0s 78ms/step - loss: 0.3896 - accuracy: 0.8977 - val_loss: 0.6986 - val_accuracy: 0.7692
# Epoch 44/50
# 5/5 [==============================] - 0s 94ms/step - loss: 0.3737 - accuracy: 0.8977 - val_loss: 0.6868 - val_accuracy: 0.8000
# Epoch 45/50
# 5/5 [==============================] - 0s 77ms/step - loss: 0.3669 - accuracy: 0.8880 - val_loss: 0.7185 - val_accuracy: 0.7692
# Epoch 46/50
# 5/5 [==============================] - 0s 79ms/step - loss: 0.3468 - accuracy: 0.9073 - val_loss: 0.6900 - val_accuracy: 0.8077
# Epoch 47/50
# 5/5 [==============================] - 0s 88ms/step - loss: 0.3614 - accuracy: 0.8784 - val_loss: 0.6686 - val_accuracy: 0.8000
# Epoch 48/50
# 5/5 [==============================] - 1s 118ms/step - loss: 0.3208 - accuracy: 0.9151 - val_loss: 0.7728 - val_accuracy: 0.7385
# Epoch 49/50
# 5/5 [==============================] - 0s 101ms/step - loss: 0.3102 - accuracy: 0.9208 - val_loss: 0.7218 - val_accuracy: 0.7923
# Epoch 50/50
# 5/5 [==============================] - 0s 99ms/step - loss: 0.2993 - accuracy: 0.9189 - val_loss: 0.7268 - val_accuracy: 0.7615

# %% [markdown]
# Fitting the model with the data and finding out the accuracy at each epoch to see how our model is learning. Now we will train our model on 50 epochs and a batch size of 128. You can try using more number of epochs to increase accuracy but here we can see that the model has already reached a very high accuracy so we don't need to run it for more. During each epochs we can see how the model is performing by viewing the training and validation accuracy.

# %%
# Saving model
model.save("/content/drive/My Drive/bird_species.h5")

# %% [markdown]
# Now we will save the model in h5 format to use it later for prediction.

# %%
#Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# Next we will plot the accuracy of the model for the training history.

# %%
#Plot the loss history
plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], color='r')
plt.plot(history.history['val_loss'], color='b')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# Here we will plot the loss of the model for the training history.

# %%
# Calculating test accuracy
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# 6/6 [==============================] - 0s 26ms/step - loss: 0.7432 - accuracy: 0.7791
# Test Accuracy: 77.91411280632019

# %% [markdown]
# Evaluating the model to know the accuracy of the model on the test data.

# %%
# Storing predictions
y_pred = model.predict(x_test)
# Out:
# 6/6 [==============================] - 0s 10ms/step

# %% [markdown]
# Here we are storing prediction on test data.

# %%
# Plotting image to compare
img = array_to_img(x_test[5])
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %% [markdown]
# Visualizing one of the image which we will be further used for prediction.

# %%
# Finding max value from predition list and comaparing original value vs predicted
labels = lb.classes_
print(labels)
print("Originally : ",labels[np.argmax(y_test[5])])
print("Predicted : ",labels[np.argmax(y_pred[5])])
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER'
#  'EMPEROR PENGUIN' 'FLAMINGO']
# Originally :  CARMINE BEE-EATER
# Predicted :  CARMINE BEE-EATER

# %% [markdown]
# Now, we will create list of labels using object of label binarizer. We will print that list and finally we will print out the prediction and the original label of the image we visualized above using argmax().

# %% [markdown]
# # Conclusion:

# %% [markdown]
# We started with loading the dataset into google colab using google drive and visualizing the images. Normalizing is an important step when working with any type of dataset. After that we created a CNN Model which is further used for predicting the bird species using the image supplied to model.

# %% [markdown]
# # Scope:

# %% [markdown]
# This project can be used for educational purposes to get a better understanding of how to create network architecture for a CNN model. You can further hyper parameter tune this model to reach a higher accuracy. It can be used by bird sanctuaries to identify different types of birds.
